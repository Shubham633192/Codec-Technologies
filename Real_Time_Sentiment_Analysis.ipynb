# %%
/content/drive/MyDrive/Codec Tech Internship/tweets_sample_large.csv

# %% [markdown]
# # **Real-Time Sentiment Analysis**

# %%
# !pip install textblob --quiet

import pandas as pd
import matplotlib.pyplot as plt
from textblob import TextBlob

# %% [markdown]
# **Load data**

# %%
df = pd.read_csv('/content/drive/MyDrive/Codec Tech Internship/tweets_sample_large.csv')

# %%
df
# Out:
#                               text
# 0            Absolutely love this!
# 1           Worst experience ever.
# 2              Not bad, not great.
# 3   I'm so happy with the service!
# 4     Disappointed and frustrated.
# 5     Would recommend to everyone.
# 6            Will never buy again.
# 7                 This is amazing!
# 8                Terrible quality.
# 9                     It was okay.
# 10                 Very satisfied!
# 11                Could be better.
# 12              Top-notch support!
# 13        Extremely poor delivery.
# 14                     Five stars!
# 15                  One star only.
# 16                  No complaints.
# 17                   Huge letdown.
# 18       Exceeded my expectations.
# 19                   Not worth it.

# %% [markdown]
# **Sentiment classification**

# %%
def get_sentiment(text):
    blob = TextBlob(text)
    polarity = blob.sentiment.polarity
    if polarity > 0.1:
        return "Positive"
    elif polarity < -0.1:
        return "Negative"
    else:
        return "Neutral"

df['Sentiment'] = df['text'].apply(get_sentiment)

# %% [markdown]
# **Plot**

# %%
df['Sentiment'].value_counts().plot(kind='bar', color=['green', 'red', 'gray'])
plt.title('Tweet Sentiment')
plt.xlabel('Sentiment')
plt.ylabel('Tweet Count')
plt.grid(True)
plt.show()

# %%
df.head()
# Out:
#                              text Sentiment
# 0           Absolutely love this!  Positive
# 1          Worst experience ever.  Negative
# 2             Not bad, not great.   Neutral
# 3  I'm so happy with the service!  Positive
# 4    Disappointed and frustrated.  Negative
